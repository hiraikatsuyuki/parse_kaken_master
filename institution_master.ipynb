# %% [markdown]
# # KAKENの研究機関マスタをローカルのMariaDBに保存するプログラム

# %% [markdown]
# ### 事前準備
# - KAKENマスタデータは、git のリポジトリで管理されており、最新のデータを利用可能。
# - https://bitbucket.org/niijp/grants_masterxml_kaken/ からリポジトリを pull して、ローカルの ./grants_masterxml_kaken フォルダに同期しておく。
# - ローカルで MariaDB を動かしておく。
# - MariaDB のユーザ名、パスワード、データベース名は、下のセルから ./config.ini として保存しておく。

# %%
# encoding: utf-8
import configparser
config = configparser.ConfigParser()
config['mariadb'] = {}

# それぞれ値を入力する
config['mariadb']['username'] = ''
config['mariadb']['password'] = ''
config['mariadb']['database'] = ''

with open('config.ini', 'w') as configfile:
    config.write(configfile)

# %% [markdown]
# ### ここから本編
# bitbucketから読み込んだマスタのXMLファイルをelementTreeに変換

# %%
# encoding: utf-8
from lxml import etree
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import glob
import sqlalchemy as sa
import sqlalchemy.ext.declarative
import pymysql
import configparser

# %%
tree = etree.parse('grants_masterxml_kaken/institution_master_kakenhi.xml')

institutionlist = []
for institution_table in tree.iterfind("institution_table"):
    for institution in institution_table.iterfind("institution"):
        institutionname = institution.find("name[@lang='ja']").text
        for code in institution.iterfind("code"):
            row = [
                code.get("type"),
                code.text,
                institutionname,
            ]
            institutionlist.append(row)
            
df = pd.DataFrame(institutionlist)
df.columns = ['code_type', 'code_number', 'institution_name']
df
# Out:
#        code_type code_number                    institution_name
# 0            nii     0010101                               北海道大学
# 1           mext       10101                               北海道大学
# 2           jsps       10101                               北海道大学
# 3            nii     0010102                             北海道教育大学
# 4           mext       10102                             北海道教育大学
# 5           jsps       10102                             北海道教育大学
# 6            nii     0010103                              室蘭工業大学
# 7           mext       10103                              室蘭工業大学
# 8           jsps       10103                              室蘭工業大学
# 9            nii     0010104                              小樽商科大学
# 10          mext       10104                              小樽商科大学
# 11          jsps       10104                              小樽商科大学
# 12           nii     0010105                              帯広畜産大学
# 13          mext       10105                              帯広畜産大学
# 14          jsps       10105                              帯広畜産大学
# 15           nii     0010106                              北見工業大学
# 16          mext       10106                              北見工業大学
# 17          jsps       10106                              北見工業大学
# 18           nii     0010107                              旭川医科大学
# 19          mext       10107                              旭川医科大学
# 20          jsps       10107                              旭川医科大学
# 21           nii     0011101                                弘前大学
# 22          mext       11101                                弘前大学
# 23          jsps       11101                                弘前大学
# 24           nii     0011201                                岩手大学
# 25          mext       11201                                岩手大学
# 26          jsps       11201                                岩手大学
# 27           nii     0011301                                東北大学
# 28          mext       11301                                東北大学
# 29          jsps       11301                                東北大学
# ...          ...         ...                                 ...
# 179932      mext       64402                             国立国際美術館
# 179933       nii     0064601                             奈良国立博物館
# 179934      mext       64601                             奈良国立博物館
# 179935       nii     0064602                          奈良国立文化財研究所
# 179936      mext       64602                          奈良国立文化財研究所
# 179937       nii     0081402                          秋田県高度技術研究所
# 179938      mext       81402                          秋田県高度技術研究所
# 179939       nii     0081403                         秋田県工業技術センター
# 179940      mext       81403                         秋田県工業技術センター
# 179941       nii     0082605                        東京都神経科学総合研究所
# 179942      mext       82605                        東京都神経科学総合研究所
# 179943       nii     0082608                             国立多摩研究所
# 179944      mext       82608                             国立多摩研究所
# 179945       nii     0082615                            日本進路指導協会
# 179946      mext       82615                            日本進路指導協会
# 179947       nii     0083202                         富山市科学文化センター
# 179948      mext       83202                         富山市科学文化センター
# 179949       nii      382757             国立障害者リハビリテーションセンター(研究所)
# 179950      mext       82404             国立障害者リハビリテーションセンター(研究所)
# 179951       nii      382761                国立研究開発法人国立国際医療研究センター
# 179952      mext       82610                国立研究開発法人国立国際医療研究センター
# 179953       nii      382773     独立行政法人国立病院機構(名古屋医療センター臨床研究センター)
# 179954      mext       83904     独立行政法人国立病院機構(名古屋医療センター臨床研究センター)
# 179955       nii      382783  熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 179956      mext       87402  熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 179957      jsps       87402  熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 179958       nii      382868                       奈良県農業研究開発センター
# 179959      mext       84605                       奈良県農業研究開発センター
# 179960       nii      382699                国際連合大学サステイナビリティ高等研究所
# 179961      mext       82691                国際連合大学サステイナビリティ高等研究所
#
# [179962 rows x 3 columns]

# %% [markdown]
# 重複のデータがあるかどうか

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# 重複データがあった。dropしておく。

# %%
df = df.drop_duplicates()
df
# Out:
#        code_type code_number                    institution_name
# 0            nii     0010101                               北海道大学
# 1           mext       10101                               北海道大学
# 2           jsps       10101                               北海道大学
# 3            nii     0010102                             北海道教育大学
# 4           mext       10102                             北海道教育大学
# 5           jsps       10102                             北海道教育大学
# 6            nii     0010103                              室蘭工業大学
# 7           mext       10103                              室蘭工業大学
# 8           jsps       10103                              室蘭工業大学
# 9            nii     0010104                              小樽商科大学
# 10          mext       10104                              小樽商科大学
# 11          jsps       10104                              小樽商科大学
# 12           nii     0010105                              帯広畜産大学
# 13          mext       10105                              帯広畜産大学
# 14          jsps       10105                              帯広畜産大学
# 15           nii     0010106                              北見工業大学
# 16          mext       10106                              北見工業大学
# 17          jsps       10106                              北見工業大学
# 18           nii     0010107                              旭川医科大学
# 19          mext       10107                              旭川医科大学
# 20          jsps       10107                              旭川医科大学
# 21           nii     0011101                                弘前大学
# 22          mext       11101                                弘前大学
# 23          jsps       11101                                弘前大学
# 24           nii     0011201                                岩手大学
# 25          mext       11201                                岩手大学
# 26          jsps       11201                                岩手大学
# 27           nii     0011301                                東北大学
# 28          mext       11301                                東北大学
# 29          jsps       11301                                東北大学
# ...          ...         ...                                 ...
# 179461       nii     0082615                            日本進路指導協会
# 179462      mext       82615                            日本進路指導協会
# 179463       nii     0083202                         富山市科学文化センター
# 179464      mext       83202                         富山市科学文化センター
# 179465       nii     0083904                   国立名古屋病院(臨床研究センター)
# 179466      mext       83904                   国立名古屋病院(臨床研究センター)
# 179467       nii     0084605                         奈良県農業技術センター
# 179468      mext       84605                         奈良県農業技術センター
# 179469       nii     0087402                         熊本県工業技術センター
# 179470      mext       87402                         熊本県工業技術センター
# 179471      jsps       87402                         熊本県工業技術センター
# 179531       nii      382759                          国立国際医療センター
# 179532      mext       82610                          国立国際医療センター
# 179592       nii      382773     独立行政法人国立病院機構(名古屋医療センター臨床研究センター)
# 179593      mext       83904     独立行政法人国立病院機構(名古屋医療センター臨床研究センター)
# 179653       nii      382867                         奈良県農業総合センター
# 179654      mext       84605                         奈良県農業総合センター
# 179708       nii      382757             国立障害者リハビリテーションセンター(研究所)
# 179709      mext       82404             国立障害者リハビリテーションセンター(研究所)
# 179772       nii      382783  熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 179773      mext       87402  熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 179774      jsps       87402  熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 179829       nii      382760                  独立行政法人国立国際医療研究センター
# 179830      mext       82610                  独立行政法人国立国際医療研究センター
# 179897       nii      382868                       奈良県農業研究開発センター
# 179898      mext       84605                       奈良県農業研究開発センター
# 179951       nii      382761                国立研究開発法人国立国際医療研究センター
# 179952      mext       82610                国立研究開発法人国立国際医療研究センター
# 179960       nii      382699                国際連合大学サステイナビリティ高等研究所
# 179961      mext       82691                国際連合大学サステイナビリティ高等研究所
#
# [6799 rows x 3 columns]

# %% [markdown]
# テーブルの構造を記述する

# %%
Base = sa.ext.declarative.declarative_base()

class Institution(Base):
    __tablename__ = 'kaken_master_institution'
    id = sa.Column(sa.Integer, primary_key=True)
    code_type = sa.Column(sa.String(256))
    code_number = sa.Column(sa.Integer)
    institution_name = sa.Column(sa.String(256))

# %% [markdown]
# ローカルのmariaDBに関する設定ファイルを読み込み（config.iniはgitに上げていないが、事前準備で作られているはず）

# %%
config = configparser.ConfigParser()
config.read('config.ini')
username = config['mariadb']['username']
password = config['mariadb']['password']
database = config['mariadb']['database']
url = 'mysql+pymysql://' + username + ':' + password + '@localhost:3306/' + database + '?charset=utf8'

# %% [markdown]
# データベースにテーブル構造とデータの中身を書き込む

# %%
engine = sa.create_engine(url, echo=True)
Base.metadata.create_all(engine)
df.to_sql('kaken_master_institution', engine, if_exists='replace')
# Out:
# 2018-04-06 10:01:21,174 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2018-04-06 10:01:21,175 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,177 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2018-04-06 10:01:21,178 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,180 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8' and `Collation` = 'utf8_bin'
# 2018-04-06 10:01:21,182 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,184 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2018-04-06 10:01:21,185 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,187 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2018-04-06 10:01:21,188 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,189 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8) COLLATE utf8_bin AS anon_1
# 2018-04-06 10:01:21,190 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,192 INFO sqlalchemy.engine.base.Engine DESCRIBE `kaken_master_institution`
# 2018-04-06 10:01:21,193 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,212 INFO sqlalchemy.engine.base.Engine DESCRIBE `kaken_master_institution`
# 2018-04-06 10:01:21,213 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,228 INFO sqlalchemy.engine.base.Engine DESCRIBE `kaken_master_institution`
# 2018-04-06 10:01:21,229 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,244 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `data_analysis`
# 2018-04-06 10:01:21,245 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,247 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `kaken_master_institution`
# 2018-04-06 10:01:21,248 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,250 INFO sqlalchemy.engine.base.Engine
# DROP TABLE kaken_master_institution
# 2018-04-06 10:01:21,251 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,263 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-04-06 10:01:21,265 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE kaken_master_institution (
# 	`index` BIGINT,
# 	code_type TEXT,
# 	code_number TEXT,
# 	institution_name TEXT
# )
#
#
# 2018-04-06 10:01:21,266 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,287 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-04-06 10:01:21,288 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_kaken_master_institution_index ON kaken_master_institution (`index`)
# 2018-04-06 10:01:21,289 INFO sqlalchemy.engine.base.Engine {}
# 2018-04-06 10:01:21,299 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-04-06 10:01:21,301 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-04-06 10:01:21,373 INFO sqlalchemy.engine.base.Engine INSERT INTO kaken_master_institution (`index`, code_type, code_number, institution_name) VALUES (%(index)s, %(code_type)s, %(code_number)s, %(institution_name)s)
# 2018-04-06 10:01:21,374 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'code_type': 'nii', 'code_number': '0010101', 'institution_name': '北海道大学'}, {'index': 1, 'code_type': 'mext', 'code_number': '10101', 'institution_name': '北海道大学'}, {'index': 2, 'code_type': 'jsps', 'code_number': '10101', 'institution_name': '北海道大学'}, {'index': 3, 'code_type': 'nii', 'code_number': '0010102', 'institution_name': '北海道教育大学'}, {'index': 4, 'code_type': 'mext', 'code_number': '10102', 'institution_name': '北海道教育大学'}, {'index': 5, 'code_type': 'jsps', 'code_number': '10102', 'institution_name': '北海道教育大学'}, {'index': 6, 'code_type': 'nii', 'code_number': '0010103', 'institution_name': '室蘭工業大学'}, {'index': 7, 'code_type': 'mext', 'code_number': '10103', 'institution_name': '室蘭工業大学'}  ... displaying 10 of 6799 total bound parameter sets ...  {'index': 179960, 'code_type': 'nii', 'code_number': '382699', 'institution_name': '国際連合大学サステイナビリティ高等研究所'}, {'index': 179961, 'code_type': 'mext', 'code_number': '82691', 'institution_name': '国際連合大学サステイナビリティ高等研究所'})
# 2018-04-06 10:01:21,465 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ### おしまい
# データがコミットされていれば終了。HeidiSQLなどで、上記ドロップ済みデータフレームの件数が登録されているか確認する。
